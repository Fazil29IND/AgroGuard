# %% [markdown]
# <link rel='preconnect' href='https://fonts.googleapis.com'>
# <link rel='preconnect' href='https://fonts.gstatic.com' crossorigin>
# <link href='https://fonts.googleapis.com/css2?family=Plus+Jakarta+Sans:wght@400;500;600;700;800&family=JetBrains+Mono:wght@400;500;600&display=swap' rel='stylesheet'>
# <style>
#   .agro-hero {
#     background: linear-gradient(135deg, #0d3b1e 0%, #1b5e20 45%, #2e7d32 100%);
#     border-radius: 16px;
#     padding: 32px 28px;
#     color: #ffffff;
#     font-family: 'Plus Jakarta Sans', -apple-system, BlinkMacSystemFont, sans-serif;
#     box-shadow: 0 12px 30px -5px rgba(27, 94, 32, 0.35);
#     margin-bottom: 16px;
#   }
#   .hero-tag {
#     display: inline-flex;
#     align-items: center;
#     gap: 8px;
#     background: rgba(255, 255, 255, 0.15);
#     backdrop-filter: blur(8px);
#     padding: 6px 14px;
#     border-radius: 9999px;
#     font-size: 12px;
#     font-weight: 700;
#     letter-spacing: 0.05em;
#     text-transform: uppercase;
#     color: #d1fae5;
#     border: 1px solid rgba(255, 255, 255, 0.25);
#     margin-bottom: 14px;
#   }
#   .hero-h1 {
#     font-size: 30px;
#     font-weight: 800;
#     letter-spacing: -0.03em;
#     margin: 0 0 10px 0;
#     line-height: 1.2;
#   }
#   .hero-p {
#     font-size: 14.5px;
#     font-weight: 400;
#     color: rgba(255, 255, 255, 0.9);
#     margin: 0 0 20px 0;
#     max-width: 820px;
#     line-height: 1.6;
#   }
#   .stats-grid {
#     display: grid;
#     grid-template-columns: repeat(auto-fit, minmax(180px, 1fr));
#     gap: 12px;
#     margin-top: 18px;
#   }
#   .stat-pill {
#     background: rgba(255, 255, 255, 0.1);
#     border: 1px solid rgba(255, 255, 255, 0.15);
#     border-radius: 10px;
#     padding: 12px 16px;
#     backdrop-filter: blur(4px);
#   }
#   .stat-label {
#     font-size: 11px;
#     font-weight: 600;
#     text-transform: uppercase;
#     letter-spacing: 0.05em;
#     color: #a7f3d0;
#   }
#   .stat-val {
#     font-size: 18px;
#     font-weight: 800;
#     margin-top: 4px;
#     color: #ffffff;
#     font-family: 'JetBrains Mono', monospace;
#   }
# </style>
# <div class='agro-hero'>
#   <div class='hero-tag'>☁️ AgroGuard AI v1.0 · Kaggle Cloud GPU Edition</div>
#   <h1 class='hero-h1'>Single Unified Agricultural Vision Diagnostic Engine</h1>
#   <p class='hero-p'>
#     Scalable cloud training pipeline for <b>ConvNeXt-Tiny</b> running on Kaggle Free Cloud GPUs (NVIDIA Tesla T4 x 2 or P100).
#     Trained on the standardized <b>Dataset.zip (51,320 images across 48 classes)</b>.
#     Outputs production weights <code>best_agroguard_model.pth</code> ready to download and paste into the AgroGuard local web app.
#   </p>
#   <div class='stats-grid'>
#     <div class='stat-pill'>
#       <div class='stat-label'>Total Images</div>
#       <div class='stat-val'>51,320</div>
#     </div>
#     <div class='stat-pill'>
#       <div class='stat-label'>Unified Classes</div>
#       <div class='stat-val'>48</div>
#     </div>
#     <div class='stat-pill'>
#       <div class='stat-label'>Kaggle Accelerators</div>
#       <div class='stat-val'>Tesla T4 / P100</div>
#     </div>
#     <div class='stat-pill'>
#       <div class='stat-label'>Architecture</div>
#       <div class='stat-val'>ConvNeXt-Tiny</div>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <link rel='preconnect' href='https://fonts.googleapis.com'>
# <link rel='preconnect' href='https://fonts.gstatic.com' crossorigin>
# <link href='https://fonts.googleapis.com/css2?family=Plus+Jakarta+Sans:wght@400;500;600;700;800&family=JetBrains+Mono:wght@400;500;600&display=swap' rel='stylesheet'>
# <style>
#   .agro-card {
#     background: linear-gradient(135deg, #0d3b1e 0%, #1b5e20 50%, #2e7d32 100%);
#     border-radius: 14px;
#     padding: 24px 28px;
#     color: #ffffff;
#     font-family: 'Plus Jakarta Sans', -apple-system, BlinkMacSystemFont, sans-serif;
#     box-shadow: 0 10px 25px -5px rgba(27, 94, 32, 0.25);
#     margin-bottom: 12px;
#   }
#   .agro-badge {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     background: rgba(255, 255, 255, 0.15);
#     backdrop-filter: blur(8px);
#     padding: 4px 12px;
#     border-radius: 9999px;
#     font-size: 11px;
#     font-weight: 700;
#     letter-spacing: 0.05em;
#     text-transform: uppercase;
#     color: #e8f5e9;
#     border: 1px solid rgba(255, 255, 255, 0.2);
#     margin-bottom: 10px;
#   }
#   .agro-title {
#     font-size: 22px;
#     font-weight: 800;
#     letter-spacing: -0.02em;
#     margin: 0 0 6px 0;
#     color: #ffffff;
#   }
#   .agro-subtitle {
#     font-size: 13px;
#     font-weight: 400;
#     color: rgba(255, 255, 255, 0.85);
#     margin: 0;
#     line-height: 1.5;
#   }
# </style>
# <div class='agro-card'>
#   <div class='agro-badge'>🌿 Cloud Setup</div>
#   <div class='agro-title'>Module 1: Kaggle Cloud GPU Runtime & Storage Topology</div>
#   <div class='agro-subtitle'>Inspects Kaggle virtual environment, allocates CUDA GPU accelerators, and establishes writable output storage.</div>
# </div>

# %%
# ============================================================
# MODULE 1: KAGGLE CLOUD GPU & STORAGE DISCOVERY
# ============================================================
import os
import sys
import glob
import shutil
import zipfile
import time
import json
import warnings
warnings.filterwarnings('ignore')

import torch
import torch.nn as nn

print("=" * 80)
print("  AgroGuard AI v4.0: Kaggle Cloud GPU Unified Vision Pipeline")
print("=" * 80)

IN_KAGGLE = os.path.exists('/kaggle/working')
OUTPUT_DIR = '/kaggle/working' if IN_KAGGLE else os.getcwd()

if torch.cuda.is_available():
    device = torch.device('cuda')
    gpu_count = torch.cuda.device_count()
    gpu_name = torch.cuda.get_device_name(0)
    vram_gb = torch.cuda.get_device_properties(0).total_memory / (1024**3)
    torch.backends.cudnn.benchmark = True
    print(f"✅ Kaggle CUDA GPU Accelerator Detected!")
    print(f"   Device Name   : {gpu_name} ({gpu_count} GPU{'s' if gpu_count > 1 else ''})")
    print(f"   Dedicated VRAM: {vram_gb:.2f} GB")
else:
    device = torch.device('cpu')
    vram_gb = 0.0
    print("⚠️ GPU not selected. In Kaggle, go to Settings -> Accelerator -> GPU T4 x 2 or P100.")

print(f"   Writable Dir  : {OUTPUT_DIR}")
print("=" * 80)

# %% [markdown]
# <link rel='preconnect' href='https://fonts.googleapis.com'>
# <link rel='preconnect' href='https://fonts.gstatic.com' crossorigin>
# <link href='https://fonts.googleapis.com/css2?family=Plus+Jakarta+Sans:wght@400;500;600;700;800&family=JetBrains+Mono:wght@400;500;600&display=swap' rel='stylesheet'>
# <style>
#   .agro-card {
#     background: linear-gradient(135deg, #0d3b1e 0%, #1b5e20 50%, #2e7d32 100%);
#     border-radius: 14px;
#     padding: 24px 28px;
#     color: #ffffff;
#     font-family: 'Plus Jakarta Sans', -apple-system, BlinkMacSystemFont, sans-serif;
#     box-shadow: 0 10px 25px -5px rgba(27, 94, 32, 0.25);
#     margin-bottom: 12px;
#   }
#   .agro-badge {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     background: rgba(255, 255, 255, 0.15);
#     backdrop-filter: blur(8px);
#     padding: 4px 12px;
#     border-radius: 9999px;
#     font-size: 11px;
#     font-weight: 700;
#     letter-spacing: 0.05em;
#     text-transform: uppercase;
#     color: #e8f5e9;
#     border: 1px solid rgba(255, 255, 255, 0.2);
#     margin-bottom: 10px;
#   }
#   .agro-title {
#     font-size: 22px;
#     font-weight: 800;
#     letter-spacing: -0.02em;
#     margin: 0 0 6px 0;
#     color: #ffffff;
#   }
#   .agro-subtitle {
#     font-size: 13px;
#     font-weight: 400;
#     color: rgba(255, 255, 255, 0.85);
#     margin: 0;
#     line-height: 1.5;
#   }
# </style>
# <div class='agro-card'>
#   <div class='agro-badge'>🌿 Kaggle Extraction</div>
#   <div class='agro-title'>Module 2: Dataset.zip Extraction in Kaggle</div>
#   <div class='agro-subtitle'>Locates uploaded Dataset.zip from /kaggle/input and extracts the 51,320 images into /kaggle/working/Dataset.</div>
# </div>

# %%
# ============================================================
# MODULE 2: KAGGLE DATASET EXTRACTION
# ============================================================

# Search for Dataset.zip in Kaggle input or current working directory
DATASET_DIR = os.path.join(OUTPUT_DIR, "Dataset")

if not (os.path.exists(DATASET_DIR) and os.path.exists(os.path.join(DATASET_DIR, "train"))):
    zip_found = None
    
    # 1. Check /kaggle/input
    if os.path.exists('/kaggle/input'):
        for root, _, files in os.walk('/kaggle/input'):
            for f in files:
                if f.lower().endswith('.zip') and ('dataset' in f.lower() or 'agro' in f.lower()):
                    zip_found = os.path.join(root, f)
                    break
            if zip_found:
                break
                
    # 2. Check current directory
    if not zip_found:
        for f in os.listdir(OUTPUT_DIR):
            if f.lower().endswith('.zip') and 'dataset' in f.lower():
                zip_found = os.path.join(OUTPUT_DIR, f)
                break
                
    if zip_found:
        print(f"📦 Found dataset archive: {zip_found}")
        print(f"⏳ Extracting to {OUTPUT_DIR}...")
        with zipfile.ZipFile(zip_found, 'r') as zf:
            zf.extractall(OUTPUT_DIR)
        print("✅ Extraction complete!")
    else:
        # Check if already extracted under /kaggle/input
        for root, dirs, _ in os.walk('/kaggle/input'):
            if 'train' in dirs and 'val' in dirs:
                DATASET_DIR = root
                print(f"✅ Found direct uncompressed dataset at: {DATASET_DIR}")
                break

if not (os.path.exists(DATASET_DIR) and os.path.exists(os.path.join(DATASET_DIR, "train"))):
    raise FileNotFoundError("Could not find Dataset. Please upload Dataset.zip to your Kaggle Notebook via '+ Add Data'.")

train_dir = os.path.join(DATASET_DIR, "train")
val_dir   = os.path.join(DATASET_DIR, "val")
test_dir  = os.path.join(DATASET_DIR, "test")

train_classes = sorted([d for d in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, d))])
print(f"📊 Dataset successfully prepared: {len(train_classes)} unified classes found.")

# %% [markdown]
# <link rel='preconnect' href='https://fonts.googleapis.com'>
# <link rel='preconnect' href='https://fonts.gstatic.com' crossorigin>
# <link href='https://fonts.googleapis.com/css2?family=Plus+Jakarta+Sans:wght@400;500;600;700;800&family=JetBrains+Mono:wght@400;500;600&display=swap' rel='stylesheet'>
# <style>
#   .agro-card {
#     background: linear-gradient(135deg, #0d3b1e 0%, #1b5e20 50%, #2e7d32 100%);
#     border-radius: 14px;
#     padding: 24px 28px;
#     color: #ffffff;
#     font-family: 'Plus Jakarta Sans', -apple-system, BlinkMacSystemFont, sans-serif;
#     box-shadow: 0 10px 25px -5px rgba(27, 94, 32, 0.25);
#     margin-bottom: 12px;
#   }
#   .agro-badge {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     background: rgba(255, 255, 255, 0.15);
#     backdrop-filter: blur(8px);
#     padding: 4px 12px;
#     border-radius: 9999px;
#     font-size: 11px;
#     font-weight: 700;
#     letter-spacing: 0.05em;
#     text-transform: uppercase;
#     color: #e8f5e9;
#     border: 1px solid rgba(255, 255, 255, 0.2);
#     margin-bottom: 10px;
#   }
#   .agro-title {
#     font-size: 22px;
#     font-weight: 800;
#     letter-spacing: -0.02em;
#     margin: 0 0 6px 0;
#     color: #ffffff;
#   }
#   .agro-subtitle {
#     font-size: 13px;
#     font-weight: 400;
#     color: rgba(255, 255, 255, 0.85);
#     margin: 0;
#     line-height: 1.5;
#   }
# </style>
# <div class='agro-card'>
#   <div class='agro-badge'>🌿 Kaggle Hyperparameters</div>
#   <div class='agro-title'>Module 3: Kaggle GPU High-Throughput Hyperparameters</div>
#   <div class='agro-subtitle'>Configured for fast parallel training with batch size 64, AMP mixed-precision, and multi-core Linux workers.</div>
# </div>

# %%
# ============================================================
# MODULE 3: HYPERPARAMETER CONFIGURATION (KAGGLE GPU)
# ============================================================
gpu_count = torch.cuda.device_count() if torch.cuda.is_available() else 0
# High-throughput batch size: 128 per GPU on dual T4 = 256 total
batch_size = (128 * gpu_count) if gpu_count > 0 else 32

CONFIG = {
    'architecture': 'ConvNeXt-Tiny',
    'backbone': 'convnext_tiny.fb_in22k_ft_in1k',
    'img_size': 256,
    'batch_size': batch_size,
    'num_workers': 4 if IN_KAGGLE else 0,
    'pin_memory': torch.cuda.is_available(),
    'persistent_workers': True if IN_KAGGLE else False,
    'use_amp': torch.cuda.is_available(),
    'lr': 2e-4,
    'min_lr': 1e-6,
    'weight_decay': 1e-2,
    'epochs': 10,
    'label_smoothing': 0.1,
    'output_model': os.path.join(OUTPUT_DIR, 'best_agroguard_model.pth')
}

AGRO_MEAN = [0.4678, 0.4931, 0.3542]
AGRO_STD  = [0.2114, 0.1983, 0.2248]

print("⚙️ Kaggle Training Hyperparameters:")
print(f"   • Detected GPUs : {gpu_count}")
for k, v in CONFIG.items():
    print(f"   • {k:<16}: {v}")

# %% [markdown]
# <link rel='preconnect' href='https://fonts.googleapis.com'>
# <link rel='preconnect' href='https://fonts.gstatic.com' crossorigin>
# <link href='https://fonts.googleapis.com/css2?family=Plus+Jakarta+Sans:wght@400;500;600;700;800&family=JetBrains+Mono:wght@400;500;600&display=swap' rel='stylesheet'>
# <style>
#   .agro-card {
#     background: linear-gradient(135deg, #0d3b1e 0%, #1b5e20 50%, #2e7d32 100%);
#     border-radius: 14px;
#     padding: 24px 28px;
#     color: #ffffff;
#     font-family: 'Plus Jakarta Sans', -apple-system, BlinkMacSystemFont, sans-serif;
#     box-shadow: 0 10px 25px -5px rgba(27, 94, 32, 0.25);
#     margin-bottom: 12px;
#   }
#   .agro-badge {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     background: rgba(255, 255, 255, 0.15);
#     backdrop-filter: blur(8px);
#     padding: 4px 12px;
#     border-radius: 9999px;
#     font-size: 11px;
#     font-weight: 700;
#     letter-spacing: 0.05em;
#     text-transform: uppercase;
#     color: #e8f5e9;
#     border: 1px solid rgba(255, 255, 255, 0.2);
#     margin-bottom: 10px;
#   }
#   .agro-title {
#     font-size: 22px;
#     font-weight: 800;
#     letter-spacing: -0.02em;
#     margin: 0 0 6px 0;
#     color: #ffffff;
#   }
#   .agro-subtitle {
#     font-size: 13px;
#     font-weight: 400;
#     color: rgba(255, 255, 255, 0.85);
#     margin: 0;
#     line-height: 1.5;
#   }
# </style>
# <div class='agro-card'>
#   <div class='agro-badge'>🌿 Field Robustness & Class Balancing</div>
#   <div class='agro-title'>Module 4: Sunlight, High-Contrast & Shadow Augmentation + Balanced Sampling</div>
#   <div class='agro-subtitle'>Engineered for field deployment under harsh tropical sunlight, glare, deep canopy shade, and 550:1 class imbalance using WeightedRandomSampler and smoothed loss weights.</div>
# </div>

# %%
# ============================================================
# MODULE 4: FIELD-ROBUST AUGMENTATION & BALANCED DATALOADERS
# Robust to Harsh Sunlight, Specular Glare, High Contrast, & Canopy Shadows
# Balanced across 48 Classes with Weighted Sampling & Effective-Loss Weights
# ============================================================
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, WeightedRandomSampler
from collections import Counter
import numpy as np

# ── Field-Resilient Sunlight, Glare, Shadow, & Contrast Augmentations ──
# Mimics open-sky tropical field conditions: harsh midday sun, canopy shadows,
# overexposed specular glare on waxy leaves, and handheld phone angle shifts.
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(CONFIG['img_size'], scale=(0.70, 1.0), interpolation=transforms.InterpolationMode.BILINEAR),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomAffine(degrees=20, translate=(0.08, 0.08), scale=(0.90, 1.10), shear=8),
    # Harsh sunlight vs deep shade: dynamic contrast & brightness expansion
    transforms.ColorJitter(brightness=0.35, contrast=0.35, saturation=0.30, hue=0.08),
    # Overcome ambient illumination shifts (direct sun vs diffuse clouds)
    transforms.RandomAutocontrast(p=0.4),
    transforms.RandomEqualize(p=0.2),
    # Specular sun reflection / cuticle solarization simulation
    transforms.RandomSolarize(threshold=200, p=0.15),
    # Camera lens dust / optical glare resilience
    transforms.RandomApply([transforms.GaussianBlur(kernel_size=(3, 3), sigma=(0.1, 1.5))], p=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=AGRO_MEAN, std=AGRO_STD),
    # Dappled canopy shadows & partial leaf occlusion simulation
    transforms.RandomErasing(p=0.25, scale=(0.02, 0.20), ratio=(0.4, 2.5), value='random')
])

eval_transform = transforms.Compose([
    transforms.Resize((CONFIG['img_size'], CONFIG['img_size']), interpolation=transforms.InterpolationMode.BILINEAR),
    transforms.ToTensor(),
    transforms.Normalize(mean=AGRO_MEAN, std=AGRO_STD)
])

train_dataset = datasets.ImageFolder(train_dir, transform=train_transform)
val_dataset   = datasets.ImageFolder(val_dir, transform=eval_transform)
test_dataset  = datasets.ImageFolder(test_dir, transform=eval_transform)

CLASS_NAMES = train_dataset.classes
NUM_CLASSES = len(CLASS_NAMES)

# ── Class Imbalance Mitigation: Dual-Stage Balancing ──
# 1. WeightedRandomSampler: Ensures minority classes (e.g., Orange Scab with 8 images)
#    are sampled frequently in every batch alongside dominant classes.
# 2. Balanced Loss Weights: Dynamically weights cross-entropy gradient penalization.
targets = train_dataset.targets
class_counts = Counter(targets)
counts_per_class = [class_counts[i] for i in range(NUM_CLASSES)]

min_cnt, max_cnt = min(counts_per_class), max(counts_per_class)
print(f" Training Set Class Distribution:")
print(f"    Min Class Samples : {min_cnt} ({CLASS_NAMES[int(np.argmin(counts_per_class))]})")
print(f"    Max Class Samples : {max_cnt} ({CLASS_NAMES[int(np.argmax(counts_per_class))]})")
print(f"    Imbalance Ratio   : {max_cnt / max(1, min_cnt):.1f}:1")

# Reciprocal frequency sample weights for DataLoader sampler (power-smoothed at 0.6)
class_sample_weights = [1.0 / (max(1, count) ** 0.6) for count in counts_per_class]
sample_weights = torch.tensor([class_sample_weights[t] for t in targets], dtype=torch.float32)

train_sampler = WeightedRandomSampler(
    weights=sample_weights,
    num_samples=len(train_dataset),
    replacement=True
)

# Smoothed class loss weights for CrossEntropyLoss
raw_weights = [(max_cnt / max(1, c)) ** 0.4 for c in counts_per_class]
class_weights = torch.tensor(raw_weights, dtype=torch.float32)
class_weights = (class_weights / class_weights.mean()).to(device)

print(f" Class Balancing Active:")
print(f"    WeightedRandomSampler: ACTIVE (smooth=0.6, samples={len(train_dataset)})")
print(f"    Loss Weights Range   : [{class_weights.min().item():.3f} - {class_weights.max().item():.3f}] (mean={class_weights.mean().item():.3f})")

train_loader = DataLoader(
    train_dataset,
    batch_size=CONFIG['batch_size'],
    sampler=train_sampler,  # Balanced sampling eliminates minority class starvation
    num_workers=CONFIG['num_workers'],
    pin_memory=CONFIG['pin_memory'],
    drop_last=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=CONFIG['batch_size'],
    shuffle=False,
    num_workers=CONFIG['num_workers'],
    pin_memory=CONFIG['pin_memory']
)

test_loader = DataLoader(
    test_dataset,
    batch_size=CONFIG['batch_size'],
    shuffle=False,
    num_workers=CONFIG['num_workers'],
    pin_memory=CONFIG['pin_memory']
)

print(f" DataLoaders Initialized with Sunlight/Shadow Augmentations & Balanced Sampling!")
print(f"    Number of Classes : {NUM_CLASSES}")
print(f"    Train Batches     : {len(train_loader)} ({len(train_dataset)} samples)")
print(f"    Val Batches       : {len(val_loader)} ({len(val_dataset)} samples)")
print(f"    Test Batches      : {len(test_loader)} ({len(test_dataset)} samples)")

# %% [markdown]
# <link rel='preconnect' href='https://fonts.googleapis.com'>
# <link rel='preconnect' href='https://fonts.gstatic.com' crossorigin>
# <link href='https://fonts.googleapis.com/css2?family=Plus+Jakarta+Sans:wght@400;500;600;700;800&family=JetBrains+Mono:wght@400;500;600&display=swap' rel='stylesheet'>
# <style>
#   .agro-card {
#     background: linear-gradient(135deg, #0d3b1e 0%, #1b5e20 50%, #2e7d32 100%);
#     border-radius: 14px;
#     padding: 24px 28px;
#     color: #ffffff;
#     font-family: 'Plus Jakarta Sans', -apple-system, BlinkMacSystemFont, sans-serif;
#     box-shadow: 0 10px 25px -5px rgba(27, 94, 32, 0.25);
#     margin-bottom: 12px;
#   }
#   .agro-badge {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     background: rgba(255, 255, 255, 0.15);
#     backdrop-filter: blur(8px);
#     padding: 4px 12px;
#     border-radius: 9999px;
#     font-size: 11px;
#     font-weight: 700;
#     letter-spacing: 0.05em;
#     text-transform: uppercase;
#     color: #e8f5e9;
#     border: 1px solid rgba(255, 255, 255, 0.2);
#     margin-bottom: 10px;
#   }
#   .agro-title {
#     font-size: 22px;
#     font-weight: 800;
#     letter-spacing: -0.02em;
#     margin: 0 0 6px 0;
#     color: #ffffff;
#   }
#   .agro-subtitle {
#     font-size: 13px;
#     font-weight: 400;
#     color: rgba(255, 255, 255, 0.85);
#     margin: 0;
#     line-height: 1.5;
#   }
# </style>
# <div class='agro-card'>
#   <div class='agro-badge'>🌿 Architecture & Multi-GPU</div>
#   <div class='agro-title'>Module 5: ConvNeXt-Tiny Neural Vision Backbone & Multi-GPU Acceleration</div>
#   <div class='agro-subtitle'>Single unified classification architecture supporting joint crop & disease prediction with automatic DataParallel on T4 x 2.</div>
# </div>

# %%
# ============================================================
# MODULE 5: MODEL INITIALIZATION & MULTI-GPU SETUP
# ============================================================

def build_convnext_model(num_classes=NUM_CLASSES):
    try:
        import timm
        print("⚡ Loading ConvNeXt-Tiny via timm (pretrained on ImageNet)...")
        return timm.create_model('convnext_tiny.fb_in22k_ft_in1k', pretrained=True, num_classes=num_classes)
    except Exception as e:
        print(f"ℹ️ Falling back to torchvision: {e}")
        from torchvision import models
        m = models.convnext_tiny(weights=models.ConvNeXt_Tiny_Weights.DEFAULT)
        in_f = m.classifier[2].in_features
        m.classifier[2] = nn.Linear(in_f, num_classes)
        return m

base_model = build_convnext_model(num_classes=NUM_CLASSES).to(device)

# Enable multi-GPU acceleration if running on Kaggle T4 x 2
if torch.cuda.device_count() > 1:
    print(f"🚀 Detected {torch.cuda.device_count()} GPUs (Tesla T4 x 2)! Wrapping with PyTorch nn.DataParallel...")
    model = nn.DataParallel(base_model)
else:
    model = base_model

total_params = sum(p.numel() for p in base_model.parameters()) / 1e6
print(f"✅ Model Ready: {total_params:.2f} Million Parameters on {device} ({torch.cuda.device_count()} GPUs)")

# %% [markdown]
# <link rel='preconnect' href='https://fonts.googleapis.com'>
# <link rel='preconnect' href='https://fonts.gstatic.com' crossorigin>
# <link href='https://fonts.googleapis.com/css2?family=Plus+Jakarta+Sans:wght@400;500;600;700;800&family=JetBrains+Mono:wght@400;500;600&display=swap' rel='stylesheet'>
# <style>
#   .agro-card {
#     background: linear-gradient(135deg, #0d3b1e 0%, #1b5e20 50%, #2e7d32 100%);
#     border-radius: 14px;
#     padding: 24px 28px;
#     color: #ffffff;
#     font-family: 'Plus Jakarta Sans', -apple-system, BlinkMacSystemFont, sans-serif;
#     box-shadow: 0 10px 25px -5px rgba(27, 94, 32, 0.25);
#     margin-bottom: 12px;
#   }
#   .agro-badge {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     background: rgba(255, 255, 255, 0.15);
#     backdrop-filter: blur(8px);
#     padding: 4px 12px;
#     border-radius: 9999px;
#     font-size: 11px;
#     font-weight: 700;
#     letter-spacing: 0.05em;
#     text-transform: uppercase;
#     color: #e8f5e9;
#     border: 1px solid rgba(255, 255, 255, 0.2);
#     margin-bottom: 10px;
#   }
#   .agro-title {
#     font-size: 22px;
#     font-weight: 800;
#     letter-spacing: -0.02em;
#     margin: 0 0 6px 0;
#     color: #ffffff;
#   }
#   .agro-subtitle {
#     font-size: 13px;
#     font-weight: 400;
#     color: rgba(255, 255, 255, 0.85);
#     margin: 0;
#     line-height: 1.5;
#   }
# </style>
# <div class='agro-card'>
#   <div class='agro-badge'>🌿 Model Training</div>
#   <div class='agro-title'>Module 6: Cloud Training Execution with PyTorch AMP</div>
#   <div class='agro-subtitle'>High-throughput mixed precision loop with automatic checkpoint serialization in /kaggle/working.</div>
# </div>

# %%
# ============================================================
# MODULE 6: CLOUD TRAINING & CHECKPOINTING LOOP (WITH LIVE TQDM)
# ============================================================
import torch.optim as optim
from tqdm.auto import tqdm

criterion = nn.CrossEntropyLoss(weight=class_weights, label_smoothing=CONFIG['label_smoothing'])
optimizer = optim.AdamW(model.parameters(), lr=CONFIG['lr'], weight_decay=CONFIG['weight_decay'])
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=CONFIG['epochs'], eta_min=CONFIG['min_lr'])
scaler = torch.cuda.amp.GradScaler(enabled=CONFIG['use_amp'])

history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}
best_val_acc = 0.0
save_path = CONFIG['output_model']

print(f"🚀 Training ConvNeXt-Tiny on Kaggle GPU for {CONFIG['epochs']} Epochs (Batch Size: {CONFIG['batch_size']})...")
print("-" * 80)

for epoch in range(1, CONFIG['epochs'] + 1):
    start_time = time.time()
    
    # Train Phase
    model.train()
    train_loss, train_correct, train_total = 0.0, 0, 0
    pbar = tqdm(train_loader, desc=f"Epoch [{epoch:02d}/{CONFIG['epochs']:02d}] Train", leave=False)
    for imgs, targets in pbar:
        imgs, targets = imgs.to(device, non_blocking=True), targets.to(device, non_blocking=True)
        optimizer.zero_grad()
        
        with torch.cuda.amp.autocast(enabled=CONFIG['use_amp']):
            outputs = model(imgs)
            loss = criterion(outputs, targets)
            
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        
        train_loss += loss.item() * imgs.size(0)
        _, preds = outputs.max(1)
        train_correct += preds.eq(targets).sum().item()
        train_total += imgs.size(0)
        
        pbar.set_postfix({
            'loss': f"{train_loss / train_total:.4f}",
            'acc': f"{100.0 * train_correct / train_total:.1f}%"
        })
        
    scheduler.step()
    tr_loss = train_loss / train_total
    tr_acc  = 100.0 * train_correct / train_total
    
    # Validation Phase
    model.eval()
    val_loss, val_correct, val_total = 0.0, 0, 0
    val_pbar = tqdm(val_loader, desc=f"Epoch [{epoch:02d}/{CONFIG['epochs']:02d}] Val  ", leave=False)
    with torch.no_grad():
        for imgs, targets in val_pbar:
            imgs, targets = imgs.to(device, non_blocking=True), targets.to(device, non_blocking=True)
            with torch.cuda.amp.autocast(enabled=CONFIG['use_amp']):
                outputs = model(imgs)
                loss = criterion(outputs, targets)
                
            val_loss += loss.item() * imgs.size(0)
            _, preds = outputs.max(1)
            val_correct += preds.eq(targets).sum().item()
            val_total += imgs.size(0)
            
            val_pbar.set_postfix({
                'loss': f"{val_loss / val_total:.4f}",
                'acc': f"{100.0 * val_correct / val_total:.1f}%"
            })
            
    v_loss = val_loss / val_total
    v_acc  = 100.0 * val_correct / val_total
    elapsed = time.time() - start_time
    
    history['train_loss'].append(tr_loss)
    history['train_acc'].append(tr_acc)
    history['val_loss'].append(v_loss)
    history['val_acc'].append(v_acc)
    
    flag = ""
    if v_acc > best_val_acc:
        best_val_acc = v_acc
        model_to_save = model.module if hasattr(model, 'module') else model
        torch.save(model_to_save.state_dict(), save_path)
        flag = " ⭐ [BEST CHECKPOINT SAVED]"
        
    print(f"Epoch [{epoch:02d}/{CONFIG['epochs']:02d}] ({elapsed:.1f}s) | "
          f"Train Loss: {tr_loss:.4f} Acc: {tr_acc:.2f}% | "
          f"Val Loss: {v_loss:.4f} Acc: {v_acc:.2f}%{flag}")

print("=" * 80)
print(f"🎉 Training Complete! Peak Val Accuracy: {best_val_acc:.2f}%")
print(f"💾 Clean Weights Saved: {save_path}")

# %% [markdown]
# <link rel='preconnect' href='https://fonts.googleapis.com'>
# <link rel='preconnect' href='https://fonts.gstatic.com' crossorigin>
# <link href='https://fonts.googleapis.com/css2?family=Plus+Jakarta+Sans:wght@400;500;600;700;800&family=JetBrains+Mono:wght@400;500;600&display=swap' rel='stylesheet'>
# <style>
#   .agro-card {
#     background: linear-gradient(135deg, #0d3b1e 0%, #1b5e20 50%, #2e7d32 100%);
#     border-radius: 14px;
#     padding: 24px 28px;
#     color: #ffffff;
#     font-family: 'Plus Jakarta Sans', -apple-system, BlinkMacSystemFont, sans-serif;
#     box-shadow: 0 10px 25px -5px rgba(27, 94, 32, 0.25);
#     margin-bottom: 12px;
#   }
#   .agro-badge {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     background: rgba(255, 255, 255, 0.15);
#     backdrop-filter: blur(8px);
#     padding: 4px 12px;
#     border-radius: 9999px;
#     font-size: 11px;
#     font-weight: 700;
#     letter-spacing: 0.05em;
#     text-transform: uppercase;
#     color: #e8f5e9;
#     border: 1px solid rgba(255, 255, 255, 0.2);
#     margin-bottom: 10px;
#   }
#   .agro-title {
#     font-size: 22px;
#     font-weight: 800;
#     letter-spacing: -0.02em;
#     margin: 0 0 6px 0;
#     color: #ffffff;
#   }
#   .agro-subtitle {
#     font-size: 13px;
#     font-weight: 400;
#     color: rgba(255, 255, 255, 0.85);
#     margin: 0;
#     line-height: 1.5;
#   }
# </style>
# <div class='agro-card'>
#   <div class='agro-badge'>🌿 Test Metrics</div>
#   <div class='agro-title'>Module 7: 3-View TTA Evaluation on Unseen Test Dataset</div>
#   <div class='agro-subtitle'>Ensemble test evaluation and accuracy metrics across unseen leaves.</div>
# </div>

# %%
# ============================================================
# MODULE 7: 3-VIEW TTA TEST SET EVALUATION
# ============================================================
import matplotlib.pyplot as plt
import numpy as np

def predict_tta(model, imgs):
    with torch.no_grad():
        with torch.cuda.amp.autocast(enabled=CONFIG['use_amp']):
            p1 = torch.softmax(model(imgs), dim=1)
            p2 = torch.softmax(model(torch.flip(imgs, dims=[3])), dim=1)
            p3 = torch.softmax(model(torch.flip(imgs, dims=[2])), dim=1)
        return (p1 + p2 + p3) / 3.0

model.load_state_dict(torch.load(save_path, map_location=device))
model.eval()

all_preds, all_targets = [], []
top5_correct, total = 0, 0

print("🔬 Running 3-View TTA on Test Dataset...")
with torch.no_grad():
    for imgs, targets in test_loader:
        imgs = imgs.to(device)
        probs = predict_tta(model, imgs).cpu()
        _, top1 = probs.max(1)
        _, top5 = probs.topk(5, dim=1)
        
        all_preds.extend(top1.numpy())
        all_targets.extend(targets.numpy())
        for t, k5 in zip(targets, top5):
            if t in k5:
                top5_correct += 1
        total += len(targets)

top1 = 100.0 * np.sum(np.array(all_preds) == np.array(all_targets)) / total
top5 = 100.0 * top5_correct / total

print("=" * 80)
print(f"🏆 TEST EVALUATION RESULTS:")
print(f"   • Unseen Test Samples : {total}")
print(f"   • Top-1 Accuracy      : {top1:.2f}%")
print(f"   • Top-5 Accuracy      : {top5:.2f}%")
print("=" * 80)

# %% [markdown]
# <link rel='preconnect' href='https://fonts.googleapis.com'>
# <link rel='preconnect' href='https://fonts.gstatic.com' crossorigin>
# <link href='https://fonts.googleapis.com/css2?family=Plus+Jakarta+Sans:wght@400;500;600;700;800&family=JetBrains+Mono:wght@400;500;600&display=swap' rel='stylesheet'>
# <style>
#   .agro-card {
#     background: linear-gradient(135deg, #0d3b1e 0%, #1b5e20 50%, #2e7d32 100%);
#     border-radius: 14px;
#     padding: 24px 28px;
#     color: #ffffff;
#     font-family: 'Plus Jakarta Sans', -apple-system, BlinkMacSystemFont, sans-serif;
#     box-shadow: 0 10px 25px -5px rgba(27, 94, 32, 0.25);
#     margin-bottom: 12px;
#   }
#   .agro-badge {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     background: rgba(255, 255, 255, 0.15);
#     backdrop-filter: blur(8px);
#     padding: 4px 12px;
#     border-radius: 9999px;
#     font-size: 11px;
#     font-weight: 700;
#     letter-spacing: 0.05em;
#     text-transform: uppercase;
#     color: #e8f5e9;
#     border: 1px solid rgba(255, 255, 255, 0.2);
#     margin-bottom: 10px;
#   }
#   .agro-title {
#     font-size: 22px;
#     font-weight: 800;
#     letter-spacing: -0.02em;
#     margin: 0 0 6px 0;
#     color: #ffffff;
#   }
#   .agro-subtitle {
#     font-size: 13px;
#     font-weight: 400;
#     color: rgba(255, 255, 255, 0.85);
#     margin: 0;
#     line-height: 1.5;
#   }
# </style>
# <div class='agro-card'>
#   <div class='agro-badge'>🌿 Model Export</div>
#   <div class='agro-title'>Module 8: Download Model & Local AgroGuard Deployment</div>
#   <div class='agro-subtitle'>Direct download instructions to transfer best_agroguard_model.pth to your local AgroGuard server.</div>
# </div>

# %%
# ============================================================
# MODULE 8: KAGGLE DOWNLOAD HELPER & DEPLOYMENT GUIDE
# ============================================================
from IPython.display import FileLink, display

print("=" * 80)
print("  📥 DOWNLOAD YOUR TRAINED MODEL FROM KAGGLE:")
print("=" * 80)

if os.path.exists(save_path):
    size_mb = os.path.getsize(save_path) / (1024 * 1024)
    print(f"✅ Found: '{save_path}' ({size_mb:.1f} MB)")
    print("Click the link below to download directly to your computer:")
    display(FileLink(os.path.basename(save_path)))
    print("\nOr in Kaggle, look at the right-hand panel -> Output -> /kaggle/working -> download 'best_agroguard_model.pth'.")
else:
    print(f"⚠️ Model file not found at {save_path}")

print("\n" + "=" * 80)
print("  🚀 DEPLOYMENT TO YOUR LOCAL AGROGUARD APP:")
print("=" * 80)
print("1. After downloading 'best_agroguard_model.pth', copy it to your AgroGuard directory:")
print("   c:\\AgroGuard\\best_agroguard_model.pth")
print("2. AgroGuard has AUTOMATIC HOT-RELOADING enabled:")
print("   - You DO NOT need to restart the FastAPI server.")
print("   - The app immediately detects 'best_agroguard_model.pth' and loads the weights into memory!")
print("   - All predictions will immediately run on your trained ConvNeXt-Tiny neural network!")
print("=" * 80)
